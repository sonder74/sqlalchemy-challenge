# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect, desc
from flask import Flask, jsonify
import datetime as dt
from datetime import datetime

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")
Base = automap_base()
Base.prepare(engine, reflect=True)

Measurement = Base.classes.measurement
Station = Base.classes.station

app = Flask(__name__)

# %%
@app.route("/")
def home():
    return (
        f"Welcome to our home page!<br/>"
        f"Available Routes:<br/>"
        f"/api/v1.0/precipitation<br/>"
        f"/api/v1.0/stations<br/>"
        f"/api/v1.0/tobs<br/>"
        f"/api/v1.0<start> (Enter a start date to view temperature observations since that time.)<br/>"
        f"/api/v1.0/<start>/<end> (Enter start and end dates to view temperature observations during that period.)"
    )

# %%
#@app.route("/api/v1.0/precipitation")
#def precipitation():
    
session = Session(engine)
precip_data = session.query(Measurement.date, Measurement.prcp).all()
session.close()
    
precip_output = []
for date, precipitation in precip_data:
    precip_dict = {}
    precip_dict["date"] = date
    precip_dict["precipitation"] = precipitation
    precip_output.append(precip_dict)

#return jsonify(precip_output)
    
print(precip_output)
# Out:
# [{'date': '2010-01-01', 'precipitation': 0.08}, {'date': '2010-01-02', 'precipitation': 0.0}, {'date': '2010-01-03', 'precipitation': 0.0}, {'date': '2010-01-04', 'precipitation': 0.0}, {'date': '2010-01-06', 'precipitation': None}, {'date': '2010-01-07', 'precipitation': 0.06}, {'date': '2010-01-08', 'precipitation': 0.0}, {'date': '2010-01-09', 'precipitation': 0.0}, {'date': '2010-01-10', 'precipitation': 0.0}, {'date': '2010-01-11', 'precipitation': 0.01}, {'date': '2010-01-12', 'precipitation': 0.0}, {'date': '2010-01-14', 'precipitation': 0.0}, {'date': '2010-01-15', 'precipitation': 0.0}, {'date': '2010-01-16', 'precipitation': 0.0}, {'date': '2010-01-17', 'precipitation': 0.0}, {'date': '2010-01-18', 'precipitation': 0.0}, {'date': '2010-01-19', 'precipitation': 0.0}, {'date': '2010-01-20', 'precipitation': 0.0}, {'date': '2010-01-21', 'precipitation': 0.0}, {'date': '2010-01-22', 'precipitation': 0.0}, {'date': '2010-01-23', 'precipitation': 0.0}, {'date': '2010-01-24', 'precipitation': 0.01}, {'date': '2010-01-25', 'precipitation': 0.0}, {'date': '2010-01-26', 'precipitation': 0.04}, {'date': '2010-01-27', 'precipitation': 0.12}, {'date': '2010-01-28', 'precipitation': 0.0}, {'date': '2010-01-30', 'precipitation': None}, {'date': '2010-01-31', 'precipitation': 0.03}, {'date': '2010-02-01', 'precipitation': 0.01}, {'date': '2010-02-03', 'precipitation': None}, {'date': '2010-02-04', 'precipitation': 0.01}, {'date': '2010-02-05', 'precipitation': 0.0}, {'date': '2010-02-06', 'precipitation': 0.0}, {'date': '2010-02-07', 'precipitation': 0.0}, {'date': '2010-02-08', 'precipitation': 0.0}, {'date': '2010-02-09', 'precipitation': 0.0}, {'date': '2010-02-11', 'precipitation': 0.0}, {'date': '2010-02-12', 'precipitation': 0.02}, {'date': '2010-02-13', 'precipitation': 0.01}, {'date': '2010-02-14', 'precipitation': 0.0}, {'date': '2010-02-15', 'precipitation': 0.0}, {'date': '2010-02-16', 'precipitation': 0.0}, {'date': '2010-02-17', 'precipitation': 0.0}, {'date': '2010-02-19', 'precipitation': None}, {'date': '2010-02-20', 'precipitation': 0.03}, {'date': '2010-02-21', 'precipitation': 0.0}, {'date': '2010-02-22', 'precipitation': 0.0}, {'date': '2010-02-23', 'precipitation': 0.0}, {'date': '2010-02-24', 'precipitation': 0.0}, {'date': '2010-02-25', 'precipitation': 0.0}, {'date': '2010-02-26', 'precipitation': 0.0}, {'date': '2010-02-28', 'precipitation': 0.0}, {'date': '2010-03-01', 'precipitation': 0.01}, {'date': '2010-03-02', 'precipitation': 0.0}, {'date': '2010-03-03', 'precipitation': 0.0}, {'date': '2010-03-04', 'precipitation': 0.12}, {'date': '2010-03-05', 'precipitation': 0.08}, {'date': '2010-03-06', 'precipitation': 0.03}, {'date': '2010-03-07', 'precipitation': 0.0}, {'date': '2010-03-08', 'precipitation': 0.43}, {'date': '2010-03-09', 'precipitation': 0.06}, {'date': '2010-03-11', 'precipitation': None}, {'date': '2010-03-12', 'precipitation': 0.0}, {'date': '2010-03-13', 'precipitation': 0.0}, {'date': '2010-03-14', 'precipitation': 0.0}, {'date': '2010-03-15', 'precipitation': 0.06}, {'date': '2010-03-17', 'precipitation': 0.0}, {'date': '2010-03-18', 'precipitation': 0.0}, {'date': '2010-03-21', 'precipitation': 0.0}, {'date': '2010-03-22', 'precipitation': 0.0}, {'date': '2010-03-23', 'precipitation': 0.0}, {'date': '2010-03-24', 'precipitation': 0.0}, {'date': '2010-03-26', 'precipitation': None}, {'date': '2010-03-27', 'precipitation': 0.0}, {'date': '2010-03-28', 'precipitation': 0.0}, {'date': '2010-03-29', 'precipitation': 0.0}, {'date': '2010-03-30', 'precipitation': 0.0}, {'date': '2010-03-31', 'precipitation': 0.0}, {'date': '2010-04-01', 'precipitation': 0.0}, {'date': '2010-04-02', 'precipitation': 0.01}, {'date': '2010-04-03', 'precipitation': 0.17}, {'date': '2010-04-04', 'precipitation': 0.15}, {'date': '2010-04-05', 'precipitation': 0.27}, {'date': '2010-04-06', 'precipitation': 0.01}, {'date': '2010-04-08', 'precipitation': 0.0}, {'date': '2010-04-09', 'precipitation': 0.01}, {'date': '20 ...

# %%
#@app.route("/api/v1.0/stations")
#def stations():
    
session = Session(engine)
same_station = session.query(Station.name).filter(Measurement.station == Station.station).distinct().all()
session.close()
    
station_output = []
for name in same_station:
    station_dict = {}
    station_dict["name"] = name
    station_output.append(station_dict)    
    
#return jsonify(station_output)

print(station_output)
# Out:
# [{'name': ('WAIKIKI 717.2, HI US',)}, {'name': ('KANEOHE 838.1, HI US',)}, {'name': ('KUALOA RANCH HEADQUARTERS 886.9, HI US',)}, {'name': ('PEARL CITY, HI US',)}, {'name': ('UPPER WAHIAWA 874.3, HI US',)}, {'name': ('WAIMANALO EXPERIMENTAL FARM, HI US',)}, {'name': ('WAIHEE 837.5, HI US',)}, {'name': ('HONOLULU OBSERVATORY 702.2, HI US',)}, {'name': ('MANOA LYON ARBO 785.2, HI US',)}]

# %%
#@app.route("/api/v1.0/tobs")
#def tobs():

session = Session(engine)
latest_date = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
session.close()

for date in latest_date:
    latest_date_dict = {}
    latest_date_dict["date"] = date

latest_date_fixed = datetime.strptime(latest_date_dict.get("date"), "%Y-%m-%d")
beginning_date = latest_date_fixed - dt.timedelta(days = 365)

session = Session(engine)
most_active_station = session.query(Measurement.station).\
    filter(Measurement.date > beginning_date).\
    group_by(Measurement.station).\
    order_by(desc(func.count(Measurement.station))).\
    first()
session.close()
    
for name in most_active_station:
    active_dict = {}
    active_dict["name"] = name
    
session = Session(engine)
dates_temps = session.query(Measurement.date, Measurement.tobs).\
    filter(Measurement.station == active_dict.get("name")).\
    filter(Measurement.date > beginning_date).\
    order_by(desc(Measurement.date)).all()
session.close()
    
dates_temps_output = []
for date, temperature in dates_temps:
    dates_temps_dict = {}
    dates_temps_dict["date"] = date
    dates_temps_dict["temperature"] = temperature
    dates_temps_output.append(dates_temps_dict)
    
#return jsonify(dates_temps_output)

print(dates_temps_output)
# Out:
# [{'date': '2017-08-23', 'temperature': 81.0}, {'date': '2017-08-22', 'temperature': 82.0}, {'date': '2017-08-21', 'temperature': 81.0}, {'date': '2017-08-20', 'temperature': 81.0}, {'date': '2017-08-19', 'temperature': 79.0}, {'date': '2017-08-18', 'temperature': 80.0}, {'date': '2017-08-15', 'temperature': 78.0}, {'date': '2017-08-14', 'temperature': 79.0}, {'date': '2017-08-13', 'temperature': 81.0}, {'date': '2017-08-12', 'temperature': 80.0}, {'date': '2017-08-11', 'temperature': 78.0}, {'date': '2017-08-10', 'temperature': 81.0}, {'date': '2017-08-09', 'temperature': 80.0}, {'date': '2017-08-08', 'temperature': 80.0}, {'date': '2017-08-07', 'temperature': 80.0}, {'date': '2017-08-06', 'temperature': 80.0}, {'date': '2017-08-05', 'temperature': 81.0}, {'date': '2017-08-04', 'temperature': 80.0}, {'date': '2017-08-03', 'temperature': 79.0}, {'date': '2017-08-02', 'temperature': 73.0}, {'date': '2017-08-01', 'temperature': 77.0}, {'date': '2017-07-31', 'temperature': 80.0}, {'date': '2017-07-30', 'temperature': 81.0}, {'date': '2017-07-29', 'temperature': 81.0}, {'date': '2017-07-28', 'temperature': 81.0}, {'date': '2017-07-27', 'temperature': 79.0}, {'date': '2017-07-26', 'temperature': 82.0}, {'date': '2017-07-25', 'temperature': 80.0}, {'date': '2017-07-24', 'temperature': 78.0}, {'date': '2017-07-23', 'temperature': 81.0}, {'date': '2017-07-22', 'temperature': 81.0}, {'date': '2017-07-21', 'temperature': 80.0}, {'date': '2017-07-20', 'temperature': 80.0}, {'date': '2017-07-18', 'temperature': 80.0}, {'date': '2017-07-17', 'temperature': 80.0}, {'date': '2017-07-16', 'temperature': 78.0}, {'date': '2017-07-15', 'temperature': 80.0}, {'date': '2017-07-14', 'temperature': 81.0}, {'date': '2017-07-13', 'temperature': 79.0}, {'date': '2017-07-12', 'temperature': 81.0}, {'date': '2017-07-11', 'temperature': 78.0}, {'date': '2017-07-10', 'temperature': 80.0}, {'date': '2017-07-09', 'temperature': 80.0}, {'date': '2017-07-08', 'temperature': 80.0}, {'date': '2017-07-07', 'temperature': 79.0}, {'date': '2017-07-06', 'temperature': 81.0}, {'date': '2017-07-05', 'temperature': 80.0}, {'date': '2017-07-04', 'temperature': 80.0}, {'date': '2017-07-03', 'temperature': 78.0}, {'date': '2017-07-02', 'temperature': 80.0}, {'date': '2017-07-01', 'temperature': 80.0}, {'date': '2017-06-30', 'temperature': 75.0}, {'date': '2017-06-29', 'temperature': 79.0}, {'date': '2017-06-28', 'temperature': 79.0}, {'date': '2017-06-27', 'temperature': 80.0}, {'date': '2017-06-26', 'temperature': 81.0}, {'date': '2017-06-25', 'temperature': 80.0}, {'date': '2017-06-24', 'temperature': 80.0}, {'date': '2017-06-23', 'temperature': 78.0}, {'date': '2017-06-22', 'temperature': 80.0}, {'date': '2017-06-21', 'temperature': 79.0}, {'date': '2017-06-20', 'temperature': 78.0}, {'date': '2017-06-19', 'temperature': 80.0}, {'date': '2017-06-18', 'temperature': 77.0}, {'date': '2017-06-17', 'temperature': 80.0}, {'date': '2017-06-16', 'temperature': 79.0}, {'date': '2017-06-15', 'temperature': 78.0}, {'date': '2017-06-14', 'temperature': 80.0}, {'date': '2017-06-13', 'temperature': 80.0}, {'date': '2017-06-12', 'temperature': 83.0}, {'date': '2017-06-11', 'temperature': 79.0}, {'date': '2017-06-10', 'temperature': 77.0}, {'date': '2017-06-09', 'temperature': 80.0}, {'date': '2017-06-08', 'temperature': 80.0}, {'date': '2017-06-07', 'temperature': 79.0}, {'date': '2017-06-06', 'temperature': 79.0}, {'date': '2017-06-05', 'temperature': 80.0}, {'date': '2017-06-04', 'temperature': 79.0}, {'date': '2017-06-03', 'temperature': 79.0}, {'date': '2017-06-02', 'temperature': 79.0}, {'date': '2017-06-01', 'temperature': 79.0}, {'date': '2017-05-31', 'temperature': 79.0}, {'date': '2017-05-30', 'temperature': 76.0}, {'date': '2017-05-29', 'temperature': 75.0}, {'date': '2017-05-28', 'temperature': 76.0}, {'date': '2017-05-27', 'temperature': 74.0}, {'date': '2017-05-25', 'temperature': 77.0}, {'date': '2017-05-24', 'temperature': 77.0}, {'date': '2017-05-23', 'temperature': 8 ...

# %%
@app.route("/api/v1.0<start>")
def start(start):
    
    for date in start:
        start_date_dict = {}
        start_date_dict["date"] = date

    start_fixed = datetime.strptime(start_date_dict.get("date"), "%Y-%m-%d")
    
    session = Session(engine)
    start_temps = session.query(Measurement.tobs).\
        filter(Measurement.date >= start_fixed)
    session.close()
    
    start_temps_data = []
    for temps in start_temps:
        start_temps_dict["temperature"] = temperature
        start_temps_data.append(start_temps_dict)

    return jsonify(start_temps_data)

    #return jsonify({"error": f"Character with real_name {real_name} not found."}), 404
